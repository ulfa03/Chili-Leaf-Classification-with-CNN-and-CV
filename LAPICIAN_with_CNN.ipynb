# %% [markdown]
# <a href="https://colab.research.google.com/github/ulfa03/Chili-Leaf-Classification-with-CNN-and-CV/blob/main/LAPICIAN_with_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Image Preprocessing: Load Train, Validation, and Test Data

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
import os
import numpy as np

train_dir = r'C:\Users\PC 08 - 316\Documents\Computer Vision\Dataset Daun Cabai\train'
target_per_class = 2300  # target maksimum per kelas

# Konfigurasi augmentasi
datagen = ImageDataGenerator(
    zoom_range=0.2,
    brightness_range=(0.8, 1.2),
    rescale=1./255,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Proses augmentasi per kelas
for class_name in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_name)
    if not os.path.isdir(class_path):
        continue

    images = [f for f in os.listdir(class_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    current_count = len(images)

    print(f"Kelas {class_name}: {current_count} gambar")

    if current_count >= target_per_class:
        print(f"  → Melewati, sudah mencapai atau melebihi {target_per_class}")
        continue

    needed = target_per_class - current_count
    print(f"  → Menambahkan {needed} gambar melalui augmentasi")

    i = 0
    while i < needed:
        img_name = images[i % len(images)]  # ambil gambar secara berulang
        img_path = os.path.join(class_path, img_name)

        img = load_img(img_path, target_size=(224, 224))
        x = img_to_array(img)
        x = np.expand_dims(x, axis=0)

        aug_iter = datagen.flow(
            x,
            batch_size=1,
            save_to_dir=class_path,
            save_prefix='aug',
            save_format='jpeg'
        )

        next(aug_iter)
        i += 1

print("Augmentasi selesai.")
# Out:
# Kelas Healthy Leaf: 550 gambar
#   → Menambahkan 1750 gambar melalui augmentasi
# Kelas Leaf Curl: 550 gambar
#   → Menambahkan 1750 gambar melalui augmentasi
# Kelas Spot Leaf: 550 gambar
#   → Menambahkan 1750 gambar melalui augmentasi
# Kelas Whitefly Leaf: 550 gambar
#   → Menambahkan 1750 gambar melalui augmentasi
# Kelas Yellowish Leaf: 550 gambar
#   → Menambahkan 1750 gambar melalui augmentasi
# Augmentasi selesai.

# %%
import os
import shutil
import random
from tqdm import tqdm

original_train_dir = r'C:\Users\PC 08 - 316\Documents\Computer Vision\Dataset Daun Cabai\train'
base_dir = r'C:\Users\PC 08 - 316\Documents\Computer Vision\Dataset Daun Cabai'

all_data_dir = os.path.join(base_dir, 'all_data')
os.makedirs(all_data_dir, exist_ok=True)

for class_name in os.listdir(original_train_dir):
    src_class_path = os.path.join(original_train_dir, class_name)
    dst_class_path = os.path.join(all_data_dir, class_name)
    shutil.move(src_class_path, dst_class_path)

train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')
for dir_path in [train_dir, val_dir, test_dir]:
    os.makedirs(dir_path, exist_ok=True)

for class_name in os.listdir(all_data_dir):
    class_path = os.path.join(all_data_dir, class_name)
    images = os.listdir(class_path)
    random.shuffle(images)

    n_total = len(images)
    n_train = int(0.8 * n_total)
    n_val = int(0.1 * n_total)
    n_test = n_total - n_train - n_val

    split_map = {
        train_dir: images[:n_train],
        val_dir: images[n_train:n_train + n_val],
        test_dir: images[n_train + n_val:]
    }

    for target_dir, image_list in split_map.items():
        class_target_path = os.path.join(target_dir, class_name)
        os.makedirs(class_target_path, exist_ok=True)
        for image_name in tqdm(image_list, desc=f"{class_name} → {os.path.basename(target_dir)}"):
            src = os.path.join(class_path, image_name)
            dst = os.path.join(class_target_path, image_name)
            shutil.copy2(src, dst)
# Out:
# Healthy Leaf → train: 100%|███████████████████████████████████████████████████████| 1729/1729 [00:08<00:00, 210.11it/s]
# Healthy Leaf → val: 100%|███████████████████████████████████████████████████████████| 216/216 [00:01<00:00, 205.28it/s]
# Healthy Leaf → test: 100%|██████████████████████████████████████████████████████████| 217/217 [00:01<00:00, 209.29it/s]
# Leaf Curl → train: 100%|██████████████████████████████████████████████████████████| 1732/1732 [00:08<00:00, 205.47it/s]
# Leaf Curl → val: 100%|██████████████████████████████████████████████████████████████| 216/216 [00:00<00:00, 217.46it/s]
# Leaf Curl → test: 100%|█████████████████████████████████████████████████████████████| 217/217 [00:01<00:00, 199.91it/s]
# Spot Leaf → train: 100%|██████████████████████████████████████████████████████████| 1720/1720 [00:08<00:00, 194.88it/s]
# Spot Leaf → val: 100%|██████████████████████████████████████████████████████████████| 215/215 [00:01<00:00, 210.77it/s]
# Spot Leaf → test: 100%|█████████████████████████████████████████████████████████████| 215/215 [00:01<00:00, 204.91it/s]
# Whitefly Leaf → train: 100%|██████████████████████████████████████████████████████| 1733/1733 [00:08<00:00, 205.90it/s]
# Whitefly Leaf → val: 100%|██████████████████████████████████████████████████████████| 216/216 [00:00<00:00, 223.39it/s]
# Whitefly Leaf → test: 100%|█████████████████████████████████████████████████████████| 218/218 [00:01<00:00, 196.83it/s]
# Yellowish Leaf → train: 100%|█████████████████████████████████████████████████████| 1734/1734 [00:08<00:00, 205.64it/s]
# Yellowish Leaf → val: 100%|█████████████████████████████████████████████████████████| 216/216 [00:01<00:00, 213.18it/s]
# Yellowish Leaf → test: 100%|████████████████████████████████████████████████████████| 218/218 [00:01<00:00, 213.77it/s]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import matplotlib.pyplot as plt

# Path direktori
train_dir = r'C:\Users\PC 08 - 316\Documents\Computer Vision\Dataset Daun Cabai\train'
test_dir = r'C:\Users\PC 08 - 316\Documents\Computer Vision\Dataset Daun Cabai\test'

label_map = {
    'Healthy Leaf': 'Healthy',
    'Yellowish Leaf': 'Yellowish',
    'Leaf Curl': 'Leaf Curl',
    'Spot Leaf': 'Leaf Spot',
    'Whitefly Leaf': 'Whitefly'
}

def count_images_per_class(directory):
    class_counts = {}
    for class_name in os.listdir(directory):
        class_path = os.path.join(directory, class_name)
        if os.path.isdir(class_path):
            num_images = len([
                f for f in os.listdir(class_path)
                if f.lower().endswith(('.jpg', '.png', '.jpeg'))
            ])
            class_counts[class_name] = num_images
    return class_counts

train_counts = count_images_per_class(train_dir)

train_counts_named = {label_map[k]: v for k, v in train_counts.items()}
print("Distribusi Kelas (Train):")
for label, count in train_counts_named.items():
    print(f"  {label}: {count}")

# Plot bar chart
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.bar(train_counts_named.keys(), train_counts_named.values(), color='skyblue')
plt.title("Train Class Distribution")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Distribusi Kelas (Train):
#   Healthy: 1729
#   Leaf Curl: 1732
#   Leaf Spot: 1720
#   Whitefly: 1733
#   Yellowish: 1733

# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Path direktori
base_dir = r'C:\Users\PC 08 - 316\Documents\Computer Vision\Dataset Daun Cabai'
train_dir = base_dir + r'\train'
val_dir = base_dir + r'\val'
test_dir = base_dir + r'\test'

# Resize ke 224x224
def custom_preprocessing(image):
    image = cv2.resize(image, (48, 48))


    image_uint8 = (image * 255).astype(np.uint8) if image.max() <= 1.0 else image.astype(np.uint8)

    if image_uint8.ndim == 3 and image_uint8.shape[2] == 3:
        gray = cv2.cvtColor(image_uint8, cv2.COLOR_RGB2GRAY)
    else:
        gray = image_uint8
    gray_blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Edge detection
    laplacian = cv2.Laplacian(gray_blurred, cv2.CV_64F, ksize=3)
    laplacian = np.uint8(np.clip(np.abs(laplacian), 0, 255))

    # Ubah ke RGB agar bisa di-overlay
    edges_color = cv2.cvtColor(laplacian, cv2.COLOR_GRAY2RGB)

    # Overlay
    overlay = cv2.addWeighted(image_uint8, 0.8, edges_color, 0.2, 0)

    # Normalisasi
    overlay = overlay.astype(np.float32) / 255.0

    return overlay

# Generator untuk training (dengan augmentasi + preprocessing)
train_datagen = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    preprocessing_function=custom_preprocessing
)

# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# Path ke gambar spesifik
base_dir = r'C:\Users\PC 08 - 316\Documents\Computer Vision\Dataset Daun Cabai'
sample_class = 'Whitefly Leaf'
img_name = 'Whitefly Leaf-25.jpg'
img_path = os.path.join(base_dir, 'train', sample_class, img_name)


img = cv2.imread(img_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_resized = cv2.resize(img_rgb, (224, 224))

# Grayscale dan blur
gray = cv2.cvtColor(img_resized, cv2.COLOR_RGB2GRAY)
gray_blurred = cv2.GaussianBlur(gray, (1, 1), 0)

# Laplacian
laplacian = cv2.Laplacian(gray_blurred, cv2.CV_64F, ksize=3)
laplacian_abs = np.uint8(np.clip(np.abs(laplacian), 0, 255))

# Visualisasi
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(img_resized)
plt.title('Original')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(gray_blurred, cmap='gray')
plt.title('Grayscale + Blur')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(laplacian_abs, cmap='gray')
plt.title('Laplacian')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# Path ke gambar spesifik
base_dir = r'C:\Users\PC 08 - 316\Documents\Computer Vision\Dataset Daun Cabai'
sample_class = 'Whitefly Leaf'
img_name = 'Whitefly Leaf-25.jpg'
img_path = os.path.join(base_dir, 'train', sample_class, img_name)

# Load gambar
img = cv2.imread(img_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_resized = cv2.resize(img_rgb, (224, 224))

# Grayscale
gray = cv2.cvtColor(img_resized, cv2.COLOR_RGB2GRAY)

# Gaussian Blur
gray_blurred = cv2.GaussianBlur(gray, (1, 1), 0)

# Laplacian Edge Detection setelah blur
laplacian = cv2.Laplacian(gray_blurred, cv2.CV_64F, ksize=3)
laplacian_abs = np.uint8(np.clip(np.abs(laplacian), 0, 255))
laplacian_rgb = cv2.cvtColor(laplacian_abs, cv2.COLOR_GRAY2RGB)

# Overlay
overlay = cv2.addWeighted(img_resized, 0.8, laplacian_rgb, 0.2, 0)

# Visualisasi
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(img_resized)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(laplacian_abs, cmap='gray')
plt.title('Laplacian (with Blur)')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(overlay)
plt.title('Overlay: Image + Laplacian')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
test_val_datagen = ImageDataGenerator(rescale=1./255)

# target size 48 x 48
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

# target size 48 x 48
val_generator = test_val_datagen.flow_from_directory(
    val_dir,
    target_size=(48, 48),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# target size 48 x 48
test_generator = test_val_datagen.flow_from_directory(
    test_dir,
    target_size=(48, 48),  # samakan dengan input model
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 8647 images belonging to 5 classes.
# Found 1079 images belonging to 5 classes.
# Found 1085 images belonging to 5 classes.

# %% [markdown]
# Build Model (CNN)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

model = Sequential()
# Convolutional layer pertama
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Convolutional layer kedua
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Convolutional layer ketiga
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten layer
model.add(Flatten())

# Fully connected layer pertama
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(train_generator.num_classes, activation='softmax'))

# Compile model
model.compile(optimizer=Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# Cek arsitektur model
model.summary()
# Out:
# C:\Users\PC 08 - 316\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 46, 46, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 23, 23, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 21, 21, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │           1,285 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 619,077 (2.36 MB)
#  Trainable params: 619,077 (2.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Training Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

checkpoint = ModelCheckpoint(
    'best_model.keras',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

# ReduceLROnPlateau: mengurangi learning rate saat val_loss stagnan
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-6,
    verbose=1
)

# EarlyStopping: hentikan training jika val_loss tidak membaik
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=4,             # berhenti jika tidak ada perbaikan dalam 3 epoch
    restore_best_weights=True,  # kembali ke model dengan val_loss terbaik
    verbose=1
)

# Gabungkan semua callback
callbacks = [checkpoint, reduce_lr, early_stop]

# Training model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=50,
    callbacks=callbacks
)
# Out:
# C:\Users\PC 08 - 316\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3379 - loss: 1.4719
# Epoch 1: val_loss improved from inf to 1.26287, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 18s 63ms/step - accuracy: 0.3382 - loss: 1.4714 - val_accuracy: 0.4699 - val_loss: 1.2629 - learning_rate: 1.0000e-04
# Epoch 2/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5603 - loss: 1.0787
# Epoch 2: val_loss improved from 1.26287 to 1.12289, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 61ms/step - accuracy: 0.5603 - loss: 1.0786 - val_accuracy: 0.5607 - val_loss: 1.1229 - learning_rate: 1.0000e-04
# Epoch 3/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6096 - loss: 0.9506
# Epoch 3: val_loss improved from 1.12289 to 1.00714, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 16s 60ms/step - accuracy: 0.6096 - loss: 0.9505 - val_accuracy: 0.5968 - val_loss: 1.0071 - learning_rate: 1.0000e-04
# Epoch 4/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6332 - loss: 0.8775
# Epoch 4: val_loss improved from 1.00714 to 0.93930, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 16s 61ms/step - accuracy: 0.6332 - loss: 0.8775 - val_accuracy: 0.6302 - val_loss: 0.9393 - learning_rate: 1.0000e-04
# Epoch 5/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6669 - loss: 0.8084
# Epoch 5: val_loss improved from 0.93930 to 0.86117, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 61ms/step - accuracy: 0.6669 - loss: 0.8083 - val_accuracy: 0.6525 - val_loss: 0.8612 - learning_rate: 1.0000e-04
# Epoch 6/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6953 - loss: 0.7609
# Epoch 6: val_loss improved from 0.86117 to 0.84842, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.6953 - loss: 0.7609 - val_accuracy: 0.6534 - val_loss: 0.8484 - learning_rate: 1.0000e-04
# Epoch 7/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7098 - loss: 0.7284
# Epoch 7: val_loss did not improve from 0.84842
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.7098 - loss: 0.7283 - val_accuracy: 0.6589 - val_loss: 0.9029 - learning_rate: 1.0000e-04
# Epoch 8/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7256 - loss: 0.6862
# Epoch 8: val_loss improved from 0.84842 to 0.79354, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.7257 - loss: 0.6862 - val_accuracy: 0.6979 - val_loss: 0.7935 - learning_rate: 1.0000e-04
# Epoch 9/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7470 - loss: 0.6619
# Epoch 9: val_loss improved from 0.79354 to 0.70237, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.7470 - loss: 0.6618 - val_accuracy: 0.7294 - val_loss: 0.7024 - learning_rate: 1.0000e-04
# Epoch 10/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7468 - loss: 0.6427
# Epoch 10: val_loss did not improve from 0.70237
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.7469 - loss: 0.6427 - val_accuracy: 0.7127 - val_loss: 0.7371 - learning_rate: 1.0000e-04
# Epoch 11/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7674 - loss: 0.5900
# Epoch 11: val_loss did not improve from 0.70237
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.7674 - loss: 0.5900 - val_accuracy: 0.7331 - val_loss: 0.7125 - learning_rate: 1.0000e-04
# Epoch 12/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7743 - loss: 0.5713
# Epoch 12: val_loss improved from 0.70237 to 0.67749, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.7744 - loss: 0.5712 - val_accuracy: 0.7433 - val_loss: 0.6775 - learning_rate: 5.0000e-05
# Epoch 13/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7965 - loss: 0.5328
# Epoch 13: val_loss improved from 0.67749 to 0.62947, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.7965 - loss: 0.5328 - val_accuracy: 0.7637 - val_loss: 0.6295 - learning_rate: 5.0000e-05
# Epoch 14/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7856 - loss: 0.5516
# Epoch 14: val_loss improved from 0.62947 to 0.61822, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.7856 - loss: 0.5515 - val_accuracy: 0.7600 - val_loss: 0.6182 - learning_rate: 5.0000e-05
# Epoch 15/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7937 - loss: 0.5336
# Epoch 15: val_loss improved from 0.61822 to 0.58173, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 63ms/step - accuracy: 0.7937 - loss: 0.5336 - val_accuracy: 0.7813 - val_loss: 0.5817 - learning_rate: 5.0000e-05
# Epoch 16/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7951 - loss: 0.5247
# Epoch 16: val_loss improved from 0.58173 to 0.56774, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.7951 - loss: 0.5247 - val_accuracy: 0.7850 - val_loss: 0.5677 - learning_rate: 5.0000e-05
# Epoch 17/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8003 - loss: 0.5145
# Epoch 17: val_loss improved from 0.56774 to 0.55608, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.8004 - loss: 0.5144 - val_accuracy: 0.7905 - val_loss: 0.5561 - learning_rate: 5.0000e-05
# Epoch 18/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8030 - loss: 0.5068
# Epoch 18: val_loss improved from 0.55608 to 0.54209, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 63ms/step - accuracy: 0.8030 - loss: 0.5068 - val_accuracy: 0.7961 - val_loss: 0.5421 - learning_rate: 5.0000e-05
# Epoch 19/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8112 - loss: 0.4819
# Epoch 19: val_loss did not improve from 0.54209
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.8112 - loss: 0.4820 - val_accuracy: 0.7841 - val_loss: 0.5887 - learning_rate: 5.0000e-05
# Epoch 20/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8144 - loss: 0.4773
# Epoch 20: val_loss did not improve from 0.54209
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.8144 - loss: 0.4773 - val_accuracy: 0.7766 - val_loss: 0.6014 - learning_rate: 5.0000e-05
# Epoch 21/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8094 - loss: 0.4747
# Epoch 21: val_loss did not improve from 0.54209
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.8094 - loss: 0.4747 - val_accuracy: 0.7878 - val_loss: 0.5613 - learning_rate: 2.5000e-05
# Epoch 22/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8235 - loss: 0.4739
# Epoch 22: val_loss improved from 0.54209 to 0.54145, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 63ms/step - accuracy: 0.8235 - loss: 0.4739 - val_accuracy: 0.7970 - val_loss: 0.5415 - learning_rate: 2.5000e-05
# Epoch 23/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8203 - loss: 0.4704
# Epoch 23: val_loss did not improve from 0.54145
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 64ms/step - accuracy: 0.8203 - loss: 0.4703 - val_accuracy: 0.7905 - val_loss: 0.5618 - learning_rate: 2.5000e-05
# Epoch 24/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8193 - loss: 0.4704
# Epoch 24: val_loss did not improve from 0.54145
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 63ms/step - accuracy: 0.8193 - loss: 0.4704 - val_accuracy: 0.8017 - val_loss: 0.5481 - learning_rate: 2.5000e-05
# Epoch 25/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8214 - loss: 0.4564
# Epoch 25: val_loss improved from 0.54145 to 0.51010, saving model to best_model.keras
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 63ms/step - accuracy: 0.8214 - loss: 0.4563 - val_accuracy: 0.8072 - val_loss: 0.5101 - learning_rate: 1.2500e-05
# Epoch 26/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8230 - loss: 0.4475
# Epoch 26: val_loss did not improve from 0.51010
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.8230 - loss: 0.4475 - val_accuracy: 0.8063 - val_loss: 0.5345 - learning_rate: 1.2500e-05
# Epoch 27/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8313 - loss: 0.4375
# Epoch 27: val_loss did not improve from 0.51010
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.8313 - loss: 0.4375 - val_accuracy: 0.8072 - val_loss: 0.5320 - learning_rate: 1.2500e-05
# Epoch 28/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8391 - loss: 0.4337
# Epoch 28: val_loss did not improve from 0.51010
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 62ms/step - accuracy: 0.8391 - loss: 0.4337 - val_accuracy: 0.8109 - val_loss: 0.5108 - learning_rate: 6.2500e-06
# Epoch 29/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8376 - loss: 0.4339
# Epoch 29: val_loss did not improve from 0.51010
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 17s 63ms/step - accuracy: 0.8376 - loss: 0.4339 - val_accuracy: 0.8119 - val_loss: 0.5248 - learning_rate: 6.2500e-06
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 25.

# %%
loss, accuracy = model.evaluate(test_generator)
print(f"Test accuracy: {accuracy:.4f}")

loss, acc = model.evaluate(test_generator)
print(f"Akurasi akhir di data test: {acc:.2f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7690 - loss: 0.5860
# Test accuracy: 0.8166
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7690 - loss: 0.5860
# Akurasi akhir di data test: 0.82

# %% [markdown]
# Plot Training History

# %%
import matplotlib.pyplot as plt

# Plot akurasi
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='o')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Confusion Matrix and Classification Report (Validation)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

Y_pred = model.predict(val_generator)
y_pred = np.argmax(Y_pred, axis=1)


y_true = val_generator.classes


cm = confusion_matrix(y_true, y_pred)

class_names = list(val_generator.class_indices.keys())

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# Classification Report:
#
#                 precision    recall  f1-score   support
#
#   Healthy Leaf       0.74      0.65      0.69       216
#      Leaf Curl       0.70      0.90      0.78       216
#      Spot Leaf       0.80      0.69      0.74       215
#  Whitefly Leaf       1.00      0.95      0.98       216
# Yellowish Leaf       0.83      0.85      0.84       216
#
#       accuracy                           0.81      1079
#      macro avg       0.81      0.81      0.81      1079
#   weighted avg       0.81      0.81      0.81      1079

# %% [markdown]
# Confusion Matrix and Classification Report (Testing)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
y_true = test_generator.classes

class_names = list(test_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()


print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Classification Report:
#
#                 precision    recall  f1-score   support
#
#   Healthy Leaf       0.74      0.66      0.70       217
#      Leaf Curl       0.72      0.93      0.81       217
#      Spot Leaf       0.80      0.67      0.73       215
#  Whitefly Leaf       1.00      0.95      0.97       218
# Yellowish Leaf       0.84      0.87      0.86       218
#
#       accuracy                           0.82      1085
#      macro avg       0.82      0.82      0.81      1085
#   weighted avg       0.82      0.82      0.81      1085

# %% [markdown]
# Save Model (TFlite)

# %%
import tensorflow as tf

model = tf.keras.models.load_model("best_model.keras")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open("modelvgg16.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\PC08-3~1\AppData\Local\Temp\tmphfpg7gui\assets
# INFO:tensorflow:Assets written to: C:\Users\PC08-3~1\AppData\Local\Temp\tmphfpg7gui\assets
